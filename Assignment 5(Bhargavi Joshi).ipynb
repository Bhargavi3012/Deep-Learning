# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab import files
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78b6aaeb-087e-444b-bd59-7eb72c61b822" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78b6aaeb-087e-444b-bd59-7eb72c61b822">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['train.csv']))

# %%
df.shape
# Out:
# (21263, 82)

# %%
df.head()
# Out:
#    number_of_elements  mean_atomic_mass  ...  wtd_std_Valence  critical_temp
# 0                   4         88.944468  ...         0.437059           29.0
# 1                   5         92.729214  ...         0.468606           26.0
# 2                   4         88.944468  ...         0.444697           19.0
# 3                   4         88.944468  ...         0.440952           22.0
# 4                   4         88.944468  ...         0.428809           23.0
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 82 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   number_of_elements               21263 non-null  int64
#  1   mean_atomic_mass                 21263 non-null  float64
#  2   wtd_mean_atomic_mass             21263 non-null  float64
#  3   gmean_atomic_mass                21263 non-null  float64
#  4   wtd_gmean_atomic_mass            21263 non-null  float64
#  5   entropy_atomic_mass              21263 non-null  float64
#  6   wtd_entropy_atomic_mass          21263 non-null  float64
#  7   range_atomic_mass                21263 non-null  float64
#  8   wtd_range_atomic_mass            21263 non-null  float64
#  9   std_atomic_mass                  21263 non-null  float64
#  10  wtd_std_atomic_mass              21263 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# number_of_elements       0
# mean_atomic_mass         0
# wtd_mean_atomic_mass     0
# gmean_atomic_mass        0
# wtd_gmean_atomic_mass    0
#                         ..
# range_Valence            0
# wtd_range_Valence        0
# std_Valence              0
# wtd_std_Valence          0
# critical_temp            0
# Length: 82, dtype: int64

# %%
df.describe()
# Out:
#        number_of_elements  mean_atomic_mass  ...  wtd_std_Valence  critical_temp
# count        21263.000000      21263.000000  ...     21263.000000   21263.000000
# mean             4.115224         87.557631  ...         0.673987      34.421219
# std              1.439295         29.676497  ...         0.455580      34.254362
# min              1.000000          6.941000  ...         0.000000       0.000210
# 25%              3.000000         72.458076  ...         0.306892       5.365000
# 50%              4.000000         84.922750  ...         0.500000      20.000000
# 75%              5.000000        100.404410  ...         1.020436      63.000000
# max              9.000000        208.980400  ...         3.000000     185.000000
#
# [8 rows x 82 columns]

# %%
df.count()
# Out:
# number_of_elements       21263
# mean_atomic_mass         21263
# wtd_mean_atomic_mass     21263
# gmean_atomic_mass        21263
# wtd_gmean_atomic_mass    21263
#                          ...
# range_Valence            21263
# wtd_range_Valence        21263
# std_Valence              21263
# wtd_std_Valence          21263
# critical_temp            21263
# Length: 82, dtype: int64

# %%
X = df.drop(['critical_temp'],axis=1)
Y=df['critical_temp']

# %%
X
# Out:
#        number_of_elements  mean_atomic_mass  ...  std_Valence  wtd_std_Valence
# 0                       4         88.944468  ...     0.433013         0.437059
# 1                       5         92.729214  ...     0.632456         0.468606
# 2                       4         88.944468  ...     0.433013         0.444697
# 3                       4         88.944468  ...     0.433013         0.440952
# 4                       4         88.944468  ...     0.433013         0.428809
# ...                   ...               ...  ...          ...              ...
# 21258                   4        106.957877  ...     0.433013         0.496904
# 21259                   5         92.266740  ...     0.400000         0.212959
# 21260                   2         99.663190  ...     0.500000         0.400000
# 21261                   2         99.663190  ...     0.500000         0.462493
# 21262                   3         87.468333  ...     1.414214         1.500000
#
# ...

# %%
Y
# Out:
# 0         29.00
# 1         26.00
# 2         19.00
# 3         22.00
# 4         23.00
#           ...
# 21258      2.44
# 21259    122.10
# 21260      1.98
# 21261      1.84
# 21262     12.80
# Name: critical_temp, Length: 21263, dtype: float64

# %%
X_train_full,X_test,Y_train_full,Y_test=train_test_split(X,Y)
X_train,X_valid,Y_train,Y_valid=train_test_split(X_train_full,Y_train_full)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (11960, 81)

# %%
X_train
# Out:
#        number_of_elements  mean_atomic_mass  ...  std_Valence  wtd_std_Valence
# 9100                    5         74.290174  ...     0.400000         0.437059
# 13902                   3         73.774260  ...     1.247219         0.850647
# 20716                   4         75.478941  ...     1.500000         1.469694
# 20567                   4        142.082000  ...     1.089725         1.036521
# 19700                   6         67.623312  ...     1.699673         1.149388
# ...                   ...               ...  ...          ...              ...
# 17277                   3         64.657503  ...     0.471405         0.040791
# 907                     4         92.209100  ...     0.433013         0.349927
# 11543                   2        197.593700  ...     1.000000         0.942809
# 19524                   5         74.147580  ...     1.356466         1.388668
# 8567                    6         84.226067  ...     0.471405         0.287779
#
# ...

# %% [markdown]
# Create a input layer

# %%
input = keras.layers.Input(shape=X_train.shape[1:])

# %%
input
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 81) dtype=float32>

# %% [markdown]
# Create the Hidden Layers using Functional Method

# %%
input.shape
# Out:
# TensorShape([None, 81])

# %%
input.dtype
# Out:
# tf.float32

# %%
hidden1 = keras.layers.Dense(60, input_dim = 16, activation="relu")(input)
hidden2 = keras.layers.Dense(40, activation="relu")(hidden1)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
hidden2 = keras.layers.Dense(20, activation="relu")(hidden1)
hidden2 = keras.layers.Dense(10, activation="relu")(hidden1)

# %%
concat = keras.layers.Concatenate()([input, hidden2])

# %%
output = keras.layers.Dense(1)(concat)

# %%
model = keras.models.Model(inputs=[input], outputs=[output])

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 81)]         0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 60)           4920        input_1[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10)           610         dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 91)           0           input_1[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(loss="mean_squared_logarithmic_error", optimizer="sgd")

# %%
fithistory = model.fit(X_train_scaled, Y_train, epochs=20,validation_data=(X_valid_scaled , Y_valid))
# Out:
# Epoch 1/20
# 374/374 [==============================] - 1s 2ms/step - loss: 1.2604 - val_loss: 0.5513
# Epoch 2/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.5066 - val_loss: 0.4847
# Epoch 3/20
# 374/374 [==============================] - 1s 1ms/step - loss: 0.4599 - val_loss: 0.4468
# Epoch 4/20
# 374/374 [==============================] - 1s 1ms/step - loss: 0.4348 - val_loss: 0.4275
# Epoch 5/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.4186 - val_loss: 0.4107
# Epoch 6/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.4053 - val_loss: 0.4007
# Epoch 7/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.3947 - val_loss: 0.3910
# Epoch 8/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.3864 - val_loss: 0.3839
# Epoch 9/20
# 374/374 [==============================] - 0s 1ms/step - loss: 0.3782 - val_loss: 0.3752
# Epoch 10/20
# ...

# %%
pd.DataFrame(fithistory.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()
